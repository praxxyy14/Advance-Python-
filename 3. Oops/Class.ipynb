# %% [markdown]
# #### Class in OOP(Object Oriented Programming)
#
# ![image.png](attachment:image.png)

# %%
a = 23 
print(type(a))
# Out:
# <class 'int'>

# %%
b = 45 
print(type(b))
# Out:
# <class 'int'>

# %%
c = [1, 2, 3, 4, 5]
print(type(c))
# Out:
# <class 'list'>

# %%
c.append(10)

# %%
c
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
d = {
    101: "Prathamesh",
    102: "Praxxyy",
    103: "Prato"
}
print(type(d))
# Out:
# <class 'dict'>

# %%
emp = {
    "id": [101, 102, 103],
    "name": ["Prathamesh", "Praxxyy", "Prato"],
    "dept": ["HR", "Sales", "Engg."],
    "sal": [27000, 32000, 48000]
}

# %%
type(emp)
# Out:
# dict

# %%
import pandas as pd
df = pd.DataFrame(emp)

# %%
df
# Out:
#     id        name   dept    sal
# 0  101  Prathamesh     HR  27000
# 1  102     Praxxyy  Sales  32000
# 2  103       Prato  Engg.  48000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### Attributes of Dataframe.
#
# 1. Shape
# 2. dtypes
# 3. Columns
# 4. index
# 5. Values

# %%
df.shape
# Out:
# (3, 4)

# %%
df.columns
# Out:
# Index(['id', 'name', 'dept', 'sal'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.dtypes
# Out:
# id       int64
# name    object
# dept    object
# sal      int64
# dtype: object

# %%
df.values
# Out:
# array([[101, 'Prathamesh', 'HR', 27000],
#        [102, 'Praxxyy', 'Sales', 32000],
#        [103, 'Prato', 'Engg.', 48000]], dtype=object)

# %% [markdown]
# ####  Functions in Dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   name    3 non-null      object
#  2   dept    3 non-null      object
#  3   sal     3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 228.0+ bytes

# %%
df.sort_values(by="sal",ascending=False)
# Out:
#     id        name   dept    sal
# 2  103       Prato  Engg.  48000
# 1  102     Praxxyy  Sales  32000
# 0  101  Prathamesh     HR  27000

# %%
df.agg({"sal":["sum","mean"]})
# Out:
#                 sal
# sum   107000.000000
# mean   35666.666667

# %%
df.head(2)
# Out:
#     id        name   dept    sal
# 0  101  Prathamesh     HR  27000
# 1  102     Praxxyy  Sales  32000

# %% [markdown]
# #### Crating a user defined class.
#
# self- is any object belonging to respective class.

# %%
class Person:
    
    # Store the attributes of class in constructor function
    def __init__(self, name, age, gender, occupation):
        self.name = name
        self.age = age
        self.gender = gender
        self.occupation = occupation

    # You can create as many functions as you want in above
    def introduce(self):
        print(f"My name is {self.name}")
        print(f"I am {self.age} years old")
        print(f"I am {self.gender}")
        print(f"I work as a {self.occupation}")

# %%
p1= Person("Prathamesh",23,"Male","Engineer")
p1

# %%
print(type(p1))
# Out:
# <class '__main__.Person'>

# %%
p1.name
# Out:
# 'Prathamesh'

# %%
p1.age
# Out:
# 23

# %%
p1.gender
# Out:
# 'Male'

# %%
p1.occupation
# Out:
# 'Engineer'

# %%
p1.occupation ="Data Scientist"

# %%
p1.occupation
# Out:
# 'Data Scientist'

# %%
p1.introduce()
# Out:
# My name is Prathamesh
# I am 23 years old
# I am Male
# I work as a Data Scientist

# %%
p2 = Person(name="Prato", age=22, gender="male", occupation="HR")
type(p2)
# Out:
# __main__.Person

# %%
p2.name
# Out:
# 'Prato'

# %%
p2.age
# Out:
# 22

# %%
p2.gender
# Out:
# 'male'

# %%
p2.occupation
# Out:
# 'HR'

# %%
p2.introduce()
# Out:
# My name is Prato
# I am 22 years old
# I am male
# I work as a HR

# %%
p3 = Person(24, "Praxxyy", "Sales", 124)

# %%
p3.name
# Out:
# 24

# %%
p3.gender
# Out:
# 'Sales'

# %%
p3.age
# Out:
# 'Praxxyy'

# %%
p3.occupation
# Out:
# 124

# %%
p3.introduce()
# Out:
# My name is 24
# I am Praxxyy years old
# I am Sales
# I work as a 124

# %%
p3

# %% [markdown]
# #### Dataclasses.
#
# in dataclass __post_init__is used for validation.

# %%
from dataclasses import dataclass
from typing import Literal

# %%
@dataclass
class Person2:
    name: str
    age: int
    gender: Literal["male", "female"]
    occupation: str

    def __post_init__(self):
        errors = []

        if type(self.name) != str:
            errors.append("Name should be a string")
        if type(self.age) != int or (self.age <= 0):
            errors.append("Age should be a positive integer")
        if self.gender not in ["male", "female"]:
            errors.append("Gender should be either male or female")
        if type(self.occupation) != str:
            errors.append("Occupation should be a string")

        if errors:
            raise ValueError("\n".join(errors))
        
    def intro(self):
        print(f"My name is {self.name}")
        print(f"I am {self.age} years old")
        print(f"I am {self.gender}")
        print(f"I work as {self.occupation}")

# %%
p4 = Person2(name= "Praxxyyyy", age=25, gender="male", occupation="Purchase")
p4
# Out:
# Person2(name='Praxxyyyy', age=25, gender='male', occupation='Purchase')

# %%
type(p4)
# Out:
# __main__.Person2

# %%
p4.name
# Out:
# 'Praxxyyyy'

# %%
p4.age
# Out:
# 25

# %%
p4.gender
# Out:
# 'male'

# %%
p4.occupation
# Out:
# 'Purchase'

# %%
p4.intro()
# Out:
# My name is Praxxyyyy
# I am 25 years old
# I am male
# I work as Purchase

# %% [markdown]
# #### Bank account class.

# %%
@dataclass
class Account:
    ac_no: int
    name: str
    bal: float

    def __post_init__(self):
        errors=[]
        
        if type(self.ac_no) !=int or self.ac_no <=0:
            errors.append("Account number should be postive integer")
        if type(self.name) != str or len(self.name) == 0:
            errors.append("Name should be a string and should not be blank")
        if type(self.bal) != float:
            errors.append("Balance should be a float type")
        if errors:
            raise ValueError("\n".join(errors))
        
    def check_balance(self):
        print(f"Current balance in {self.ac_no} is {self.bal:.2f} INR")

    def deposit(self, amt: float):
        self.bal = self.bal + amt
        print(f"Amount of {amt:.2f} INR deposited in {self.ac_no}")

    def withdraw(self, amt: float):
        if self.bal < amt:
            raise ValueError("Insufficient balance!")
        else:
            self.bal = self.bal - amt
            print(f"Amount of {amt:.2f} INR withdraw from {self.ac_no}")

    def transfer(self, amt: float, ac2):
        self.withdraw(amt)
        ac2.deposit(amt)

# %%
ac1 = Account(ac_no=1234, name="Praxxyy", bal=3000.0)

# %%
ac1
# Out:
# Account(ac_no=1234, name='Praxxyy', bal=3000.0)

# %%
ac1.ac_no
# Out:
# 1234

# %%
ac1.bal
# Out:
# 3000.0

# %%
ac1.name
# Out:
# 'Praxxyy'

# %%
ac1.check_balance()
# Out:
# Current balance in 1234 is 3000.00 INR

# %%
ac1.deposit(500.0)
# Out:
# Amount of 500.00 INR deposited in 1234

# %%
ac1.check_balance()
# Out:
# Current balance in 1234 is 3500.00 INR

# %%
ac1.withdraw(4000.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 ac1.withdraw(4000.0)
#
# Cell In[61], line 28, in Account.withdraw(self, amt)
#      26 def withdraw(self, amt: float):
#      27     if self.bal < amt:
# ---> 28         raise ValueError("Insufficient balance!")
#      29     else:
#      30         self.bal = self.bal - amt
#
# ValueError: Insufficient balance!

# %%
ac1.check_balance()
# Out:
# Current balance in 1234 is 3500.00 INR

# %%
ac1.withdraw(700.0)
# Out:
# Amount of 700.00 INR withdraw from 1234

# %%
ac1.check_balance()
# Out:
# Current balance in 1234 is 2800.00 INR

# %%
ac2 = Account(ac_no=7890, name="Prathamesh", bal=1000.0)
ac2
# Out:
# Account(ac_no=7890, name='Prathamesh', bal=1000.0)

# %%
ac2.ac_no
# Out:
# 7890

# %%
ac2.name
# Out:
# 'Prathamesh'

# %%
ac2.bal
# Out:
# 1000.0

# %%
ac2.check_balance()
# Out:
# Current balance in 7890 is 1000.00 INR

# %% [markdown]
# #### Transfer 800 INR from ac1 to ac2

# %%
ac1.transfer(800.0, ac2)
# Out:
# Amount of 800.00 INR withdraw from 1234
# Amount of 800.00 INR deposited in 7890

# %%
ac1.check_balance()
# Out:
# Current balance in 1234 is 2000.00 INR

# %%
ac2.check_balance()
# Out:
# Current balance in 7890 is 1800.00 INR

# %%
ac1.transfer(5000.0, ac2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 ac1.transfer(5000.0, ac2)
#
# Cell In[61], line 34, in Account.transfer(self, amt, ac2)
#      33 def transfer(self, amt: float, ac2):
# ---> 34     self.withdraw(amt)
#      35     ac2.deposit(amt)
#
# Cell In[61], line 28, in Account.withdraw(self, amt)
#      26 def withdraw(self, amt: float):
#      27     if self.bal < amt:
# ---> 28         raise ValueError("Insufficient balance!")
#      29     else:
#      30         self.bal = self.bal - amt
#
# ValueError: Insufficient balance!

# %% [markdown]
# #### Transferr from ac2 to ac1

# %%
ac2.transfer(900.0, ac1)
# Out:
# Amount of 900.00 INR withdraw from 7890
# Amount of 900.00 INR deposited in 1234

# %%
ac2.check_balance()
# Out:
# Current balance in 7890 is 900.00 INR

# %%
ac1.check_balance()
# Out:
# Current balance in 1234 is 2900.00 INR
